# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardoatom/Bootcamp-Data-Science/blob/main/Notebook/Aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 01**
#
# ---
#   Bootcamp de Data Science Aplicada realizado pela Alura com objetivo de aprofundar e expandir o conhecimento em linguagens que compõem a formação do cientista de dados. Ferramentas a serem utilizadas: Python, Pandas, Seaborn, Jupyter, Colab, Scikit-Learn, entre outras.
#
#
# > Importando biblioteca e dados

# %% [markdown]
# ## **Importando dados e bibliotecas**
#
# Estamos analisando gastos no ambiente hospitalar do SUS (Serviço Único de Saúde), a partir de 2008. Fonte de dados: DATASUS (https://datasus.saude.gov.br/informacoes-de-saude-tabnet/)

# %%
import pandas as pd                              
import matplotlib.pyplot as plt                  
import matplotlib.ticker as ticker


url = 'https://raw.githubusercontent.com/ricardoatom/Bootcamp-Data-Science/main/Dados/interna%C3%A7%C3%B5es.csv'

# %%
#skiprows: descartar as primeiras linhas que vieram no arquivo txt desnecessários
#sep: o arquivo veio com separados ";"
#skipfooter: descartar as últimas 12 linhas
#thousas: separar por milhares e decimal: separar as unidades decimais por "," 

dados = pd.read_csv(url, encoding = "ISO-8859-1",
                    skiprows = 3, sep=";", skipfooter=12, thousands=".", decimal = ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   import sys

# %% [markdown]
# ## **Comandos e visualizações**

# %%
#head():comando para visualizar as 5 primeiras linhas
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
#tail(): comando para visualizar as 5 últimas linhas.
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  101374341.51  1.195865e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...   19241624.02  2.172158e+09
# 24         51 Mato Grosso   4795299.01  ...   17790649.87  2.036924e+09
# 25               52 Goiás  15310637.29  ...   43984702.05  4.657350e+09
# 26    53 Distrito Federal   4745919.19  ...   26526196.39  2.429933e+09
#
# [5 rows x 154 columns]

# %%
#describe: descreve informações essenciais da tabela.
dados.describe()
# Out:
#            2008/Jan      2008/Fev  ...      2020/Jul         Total
# count  2.700000e+01  2.700000e+01  ...  2.700000e+01  2.700000e+01
# mean   1.512685e+07  2.271016e+07  ...  5.449551e+07  5.993732e+09
# std    1.915919e+07  3.087944e+07  ...  7.397429e+07  8.057807e+09
# min    6.578895e+05  7.779393e+05  ...  3.015488e+06  2.916380e+08
# 25%    4.740724e+06  7.060732e+06  ...  1.712162e+07  1.904289e+09
# 50%    7.985142e+06  1.007993e+07  ...  2.690244e+07  2.477372e+09
# 75%    1.768483e+07  2.569327e+07  ...  6.883031e+07  7.685527e+09
# max    9.167847e+07  1.486775e+08  ...  3.667212e+08  3.892955e+10
#
# [8 rows x 151 columns]

# %%
#info(): outras informações importantes da tabela.
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
#comando para mudar para mostrar em modo float.
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %% [markdown]
# Iremos nos aprofundar na análise do mês de Agosto do ano de 2008.

# %%
dados["2008/Ago"]                                                               # isso é uma série, uma coluna unica de valores.
# Out:
# 0      3231494.61
# 1      2089107.14
# 2      9352532.70
# 3       894271.18
# 4     23341218.03
# 5      1475551.38
# 6      5413710.38
# 7     15195312.89
# 8     10549176.40
# 9     27851438.72
# 10    10640817.47
# 11    12872578.37
# 12    35457038.66
# 13     9373432.00
# 14     5238398.50
# 15    46931248.28
# 16    84722528.10
# 17    12588595.77
# 18    50912706.60
# 19   184854516.35
# 20    56982774.90
# 21    31250854.33
# 22    56113054.70
# 23     9671553.45
# 24     9243148.81
# 25    20650730.67
# 26    13710857.89
# Name: 2008/Ago, dtype: float64

# %%
#comando mean(): mostra a média daquele intervalo.
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %% [markdown]
# ## **Gráfico de Barras**
#
# Começamos a ter uma visualização melhor graficamente.

# %%
#Precisamos de uma forma melhor de visualização gráfica, optando assim pelo gráfico de barras. "ax reprenta os eixos do gráfico"
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize = (15,6))

# %%
#parâmetro {x:,.2f} : queremos visualizar em float com duas casas decimais.
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize = (15,6)) 
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))                                           #nesse caso, precisamos desse import para melhorar a visualização dos dados
#Colocando um título:
plt.title("Gastos dos procedimentos hospitalares do SUS")
#show(): esconde um retorno antes do gráfico. 
plt.show()                                                                                                    #essa função tira o retorno que aparece antes do gráfico.

# %% [markdown]
# ## **Desafio 1**
#
# Escolher um título mais descritivo, que passe a mensagem adequada ao gráfico de barras.

# %%
#parâmetro {x:,.2f} : queremos visualizar em float com duas casas decimais.
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize = (15,6)) 
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))                                           #nesse caso, precisamos desse import para melhorar a visualização dos dados
#Colocando um título:
plt.title("Gastos dos procedimentos hospitalares do SUS por unidade da federação em 2008/Ago")
#show(): esconde um retorno antes do gráfico. 
plt.show()

# %% [markdown]
# ## **Desafio 2**
#
# Desafio 02: Faça a mesma análise realizada em aula, porém para o mês mais recente.

# %%
#Observamos que o último mês da base de dados é Ago/2020. Entretanto, temos um dado com erro, precisamos ajustar.
dados["2020/Ago"].replace("-",value="0")
ax = dados.plot(x="Unidade da Federação", y="2020/Jul", kind="bar", figsize = (15,6)) 
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gastos dos procedimentos hospitalares do SUS por unidade de federação em 2020/Jul")
#show(): esconde um retorno antes do gráfico. 
plt.show()

# %% [markdown]
# # **Aula 02**
#
# Nessa nova base de dados estaremos analisando os Municípios.

# %%
url2 = 'https://raw.githubusercontent.com/ricardoatom/Bootcamp-Data-Science/main/Dados/A160324189_28_143_208.csv'

# %%
dados2 = pd.read_csv(url2, encoding = "ISO-8859-1", skiprows = 3, sep=";", skipfooter=12, thousands=".", decimal = ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## **Manipulando dados**
#
# Nossa estratégia adotada diante de valores vazios será de eliminar espaços.

# %%
#observe que nesses novos dados... temos muitos espaços com "-"
dados2
# Out:
#       Unidade da Federação  1992/Mar  ...      2020/Ago          Total
# 0              11 Rondônia         -  ...    3556381.57   929129659.72
# 1                  12 Acre         -  ...             -   420668039.63
# 2              13 Amazonas         -  ...    4726485.73  1771654871.23
# 3               14 Roraima         -  ...    1524478.04   305010883.18
# 4                  15 Pará         -  ...   11559714.54  4437115730.71
# 5                 16 Amapá         -  ...     834187.31   291637984.75
# 6             17 Tocantins         -  ...    2453362.74   999998621.85
# 7              21 Maranhão         -  ...   10916718.78  3632860959.84
# 8                 22 Piauí         -  ...    7926321.69  2130616492.35
# 9                 23 Ceará         -  ...   14559529.59  6197357245.98
# 10  24 Rio Grande do Norte         -  ...    8080160.97  2477372149.60
# 11              25 Paraíba         -  ...    8585226.08  2470550104.25
# 12           26 Pernambuco         -  ...   33544876.14  8046954289.39
# 13              27 Alagoas         -  ...    6487947.82  2104405303.11
# 14              28 Sergipe         -  ...    1742127.72  1130337049.71
# 15                29 Bahia         -  ...   26023558.53  9193802684.16
# 16         31 Minas Gerais         -  ...   57473699.06 19160106499.88
# 17       32 Espírito Santo         -  ...   10824255.26  3139189177.73
# 18       33 Rio de Janeiro         -  ...   36264322.65  9696362872.68
# 19            35 São Paulo  40243.16  ...  140414944.95 38929353900.57
# 20               41 Paraná         -  ...   41542401.16 13786964617.27
# 21       42 Santa Catarina         -  ...   16991236.43  7324100054.96
# 22    43 Rio Grande do Sul         -  ...   28349257.38 11958647088.33
# 23   50 Mato Grosso do Sul         -  ...    4059220.22  2172157981.36
# 24          51 Mato Grosso         -  ...    6174224.99  2036923784.59
# 25                52 Goiás         -  ...   20242641.73  4657348958.66
# 26     53 Distrito Federal         -  ...   12044848.02  2429933198.76
#
# [27 rows x 280 columns]

# %%
#index mostra a coluna da esquerda
#usaremos o comando mean para trabalhar apenas com números que existem.
#usamos o comando tolist para mudar para lista de python que é alterável.
colunas_usaveis = dados2.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
usaveis = dados2[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
#comando para retirar a primeira coluna...
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   7407388.24   929129659.72
# 12 Acre                  10470.07   14001.71  ...   1163813.08   420668039.63
# 13 Amazonas              35752.72   45570.64  ...  13358514.02  1771654871.23
# 14 Roraima                4785.91   11858.63  ...   2739498.41   305010883.18
# 15 Pará                 181159.29  433414.74  ...  27618727.51  4437115730.71
# 16 Amapá                 33672.74  104822.98  ...   2155083.37   291637984.75
# 17 Tocantins              4113.76   76633.06  ...   4489665.87   999998621.85
# 21 Maranhão             385330.18 1018352.93  ...  24374205.15  3632860959.84
# 22 Piauí                220788.25  353468.67  ...  18019214.49  2130616492.35
# 23 Ceará                357904.65  572356.18  ...  30809221.22  6197357245.98
# 24 Rio Grande do Norte  134605.36  272088.08  ...  19593057.45  2477372149.60
# 25 Paraíba               97352.78  368130.43  ...  15491469.06  2470550104.25
# 26 Pernambuco           400640.85 1088340.42  ...  62325444.34  8046954289.39
# 27 Alagoas              104243.75  174024.90  ...  13087850.40  2104405303.11
# 28 Sergipe               27453.63   78565.19  ...   3312766.32  1130337049.71
# 29 Bahia                135146.36  448349.75  ...  58898100.40  9193802684.16
# 31 Minas Gerais         971394.37 2861781.50  ... 120467187.34 19160106499.88
# 32 Espírito Santo        57408.11  284224.80  ...  27460475.47  3139189177.73
# 33 Rio de Janeiro       469469.34  921646.57  ...  71540227.33  9696362872.68
# 35 São Paulo           1665349.90 4434168.64  ... 282709570.31 38929353900.57
# 41 Paraná               554800.22 1431708.01  ...  80320852.69 13786964617.27
# 42 Santa Catarina       693955.05 1092964.12  ...  51764534.76  7324100054.96
# 43 Rio Grande do Sul   1049252.33 3182913.14  ...  78929703.81 11958647088.33
# 50 Mato Grosso do Sul   199556.12  573675.41  ...  12508717.35  2172157981.36
# 51 Mato Grosso           63562.50  232444.62  ...  13083151.70  2036923784.59
# 52 Goiás                179395.82  418053.58  ...  33499284.38  4657348958.66
# 53 Distrito Federal     191951.47  769966.25  ...  22233542.26  2429933198.76
#
# [27 rows x 157 columns]

# %%
#usamos esse comando para identificar os 5 estados que mais gastaram.
usaveis.sort_values(by='Total',ascending=False).head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 38929353900.57
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34 19160106499.88
# 41 Paraná             554800.22 1431708.01  ...  80320852.69 13786964617.27
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81 11958647088.33
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  9696362872.68
#
# [5 rows x 157 columns]

# %%
#localiza a linha cujo índice é acre
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação 11 Rondônia    12 Acre  ...    52 Goiás 53 Distrito Federal
# 2008/Jan              1388528.39  902416.00  ... 15310637.29          4745919.19
# 2008/Fev              2931283.42 1497206.26  ... 22258668.68          7632480.67
# 2008/Mar              1541682.52 1794028.48  ... 21442515.75          9647203.26
# 2008/Abr              1525314.96 1730469.42  ... 20921212.45         11098732.99
# 2008/Mai              1645953.84 1819443.92  ... 21615970.67         12891719.72
#
# [5 rows x 27 columns]

# %% [markdown]
# ## **Transpor tabela**
#
# Estamos buscando analisar os gastos em um determinado Estado e para isso precisamos transpor a tabela, usando o comando usaveis.T.plot()

# %%
#comando para transport a tabela
usaveis.T.plot(figsize = (15,6))
#não conseguimos plotar dessa forma, pois na última linha tem o total e "quebra nosso gráfico"

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia  ...  53 Distrito Federal
# 2020/Abr               7423678.64  ...          18123899.78
# 2020/Mai               8581195.13  ...          21437430.22
# 2020/Jun               9193593.76  ...          23479773.03
# 2020/Jul               7407388.24  ...          22233542.26
# Total                929129659.72  ...        2429933198.76
#
# [5 rows x 27 columns]

# %%
usaveis1 = usaveis.T.drop('Total')
#não poderíamos usar usaveis.drop('Total'), pois por padrão, axis = 0                 axis = 1: linhas   axis = 0: colunas. 
#teríamos que usar, usaveis.drop('Total',axis=1)

# %%
usaveis1.
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# 2020/Jul               7407388.24 1163813.08  ... 33499284.38          22233542.26
#
# [5 rows x 27 columns]

# %% [markdown]
# ## **Desafio 01**
#
# Reposicionar a legenda do gráfico em uma posição mais adequada

# %%
usaveis2 = usaveis1.plot(figsize=(15,7.5))
usaveis2.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Gastos dos procedimentos hospitalares do SUS por Município")
plt.legend(bbox_to_anchor=(0.7, 0.15, 0.5, 0.85))
plt.show()

# %% [markdown]
# ## **Desafio 02**
#
#
# Plotar o gráfico de linha com apenas 5 estados de sua preferência.

# %% [markdown]
# Optei por usar os 5 estados que mais gastaram! Dessa forma usei o comando abaixo.

# %%
#usamos esse comando para identificar os 5 estados que mais gastaram.
usaveis.sort_values(by='Total',ascending=False).head()
# Out:
#                        2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                        ...
# 35 São Paulo         1665349.90 4434168.64  ... 282709570.31 38929353900.57
# 31 Minas Gerais       971394.37 2861781.50  ... 120467187.34 19160106499.88
# 41 Paraná             554800.22 1431708.01  ...  80320852.69 13786964617.27
# 43 Rio Grande do Sul 1049252.33 3182913.14  ...  78929703.81 11958647088.33
# 33 Rio de Janeiro     469469.34  921646.57  ...  71540227.33  9696362872.68
#
# [5 rows x 157 columns]

# %%
usaveis1
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37   10470.07  ...   179395.82            191951.47
# 2007/Set                 16397.03   14001.71  ...   418053.58            769966.25
# 2007/Out                133645.19   86200.85  ...  1198730.25           2165619.56
# 2007/Nov                346912.84  301323.68  ...  2712117.54           3813256.48
# 2007/Dez                711758.31  769612.36  ...  9293914.78           7121965.42
# ...                           ...        ...  ...         ...                  ...
# 2020/Mar               7174312.31 2859102.06  ... 34558308.52          19405446.88
# 2020/Abr               7423678.64 2472063.08  ... 27499307.93          18123899.78
# 2020/Mai               8581195.13 2383895.48  ... 31870107.62          21437430.22
# 2020/Jun               9193593.76 2199920.70  ... 34437633.20          23479773.03
# 2020/Jul               7407388.24 1163813.08  ... 33499284.38          22233542.26
#
# [156 rows x 27 columns]

# %%
usaveis3 = usaveis1.T.loc[["35 São Paulo", "31 Minas Gerais", "33 Rio de Janeiro", "42 Santa Catarina", "43 Rio Grande do Sul"]].T.plot(figsize=(15,6))
usaveis3.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title('Os Cinco Maiores Municípios com procedimentos hospitalares pelo SUS',size=15)
plt.show()

# %% [markdown]
# ## **Resumo**
# Como realizar um slice no DataFrame com Pandas
#
# Formas de lidar com dados faltantes
#
# Utilizar o insert do Pandas
#
# Como transpor sua matriz de dados.
